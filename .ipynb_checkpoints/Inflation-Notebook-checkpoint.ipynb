# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_inf = pd.read_excel('61111-0001.xlsx')

# %% [markdown]
# **Had to manually adjust the excel file to make it readable by pandas.**
# **The price index is set so that 2015 = 100**

# %%
df_inf.drop('Annual change in (%)', axis=1, inplace=True)

# %%
sns.set_theme()
fig = plt.figure(figsize=(10,6))

ax = fig.add_axes([0,0,1,1])

sns.scatterplot(x='Year', y='Consumer price index', data = df_inf)
fig.autofmt_xdate()

# %%
df_inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  30 non-null     object
#  1   Consumer price index  30 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 720.0+ bytes

# %%
"Need to change the data type of the year column to an int"
df_inf['Int Year'] = pd.to_numeric(df_inf['Year'])

# %%
sns.regplot(x='Int Year', y='Consumer price index', data=df_inf)
# Out:
# <AxesSubplot:xlabel='Int Year', ylabel='Consumer price index'>
