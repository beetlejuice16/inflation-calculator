# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_inf = pd.read_excel('61111-0001.xlsx')

# %% [markdown]
# **Had to manually adjust the excel file to make it readable by pandas.**
# **The index is set so that 2015 = 100**

# %%
df_inf.drop('Annual change in (%)', axis=1, inplace=True)

# %%
df_inf
# Out:
#     Year  Consumer price index
# 0   1991                  65.5
# 1   1992                  68.8
# 2   1993                  71.9
# 3   1994                  73.8
# 4   1995                  75.1
# 5   1996                  76.1
# 6   1997                  77.6
# 7   1998                  78.3
# 8   1999                  78.8
# 9   2000                  79.9
# 10  2001                  81.5
# 11  2002                  82.6
# 12  2003                  83.5
# 13  2004                  84.9
# 14  2005                  86.2
# 15  2006                  87.6
# 16  2007                  89.6
# 17  2008                  91.9
# 18  2009                  92.2
# 19  2010                  93.2
# 20  2011                  95.2
# 21  2012                  97.1
# 22  2013                  98.5
# 23  2014                  99.5
# 24  2015                 100.0
# 25  2016                 100.5
# 26  2017                 102.0
# 27  2018                 103.8
# 28  2019                 105.3
# ...

# %%
sns.set_theme()
fig = plt.figure(figsize=(10,6))

ax = fig.add_axes([0,0,1,1])

sns.scatterplot(x=df_inf['Year'], y=df_inf['Consumer price index'], ax=ax)
fig.autofmt_xdate()
